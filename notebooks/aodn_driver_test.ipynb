# %%
# print URLs from AODN cataolog
import rompy
cat = rompy.cat
print(cat.aodn.nrt_wave_bouys.urlpath)
print(cat.aodn.nrt_wave_altimetry.urlpath)
print(cat.aodn.nrt_wave_sar.urlpath)
# Out:
# http://geoserver-portal.aodn.org.au/geoserver/ows?typeName=aodn:aodn_wave_nrt_timeseries_data&SERVICE=WFS&outputFormat=csv&REQUEST=GetFeature&VERSION=1.0.0&CQL_FILTER=INTERSECTS(geom,POLYGON ((115.0000000000000000 -33.0000000000000000, 115.0000000000000000 -31.5000000000000000, 115.8000030517578125 -31.5000000000000000, 115.8000030517578125 -33.0000000000000000, 115.0000000000000000 -33.0000000000000000))) AND TIME >= '2020-02-03T00:00:00Z' AND TIME <= '2021-02-10T00:00:00Z'
# ...

# %%
# inspect AODN buoys
df=cat.aodn.nrt_wave_bouys.read()
print(len(df))
df.head
# Out:
# 3250
# <bound method NDFrame.head of                                                     FID  wmo_id  measurement  \
# 0     aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56005       304634
# 1     aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56005       304662
# 2     aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56005       304678
# 3     aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56005       304704
# 4     aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56005       304705
# ...                                                 ...     ...          ...
# 3245  aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56014       431697
# 3246  aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56014       432275
# 3247  aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56014       432415
# 3248  aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56014       432533
# 3249  aodn_wave_nrt_timeseries_data.fid-5f1bee80_178...   56014       432712
#
# ...

# %%
# inspect AODN altimetry
df=cat.aodn.nrt_wave_altimetry.read()
print(len(df))
df.head
# Out:
# 34
# /home/rfonsecadasilva/anaconda3/envs/rompy-dev/lib/python3.7/site-packages/geopandas/geodataframe.py:577: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   for feature in features_lst:
# <bound method NDFrame.head of                                                gml_id  timeseries_id  \
# 0   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2860867
# 1   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2752090
# 2   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2929084
# 3   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2810733
# 4   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2767208
# 5   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2794687
# 6   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2804339
# 7   srs_surface_waves_altimetry_map.fid--8fcb47d_1...        2879888
# ...

# %%
# inspect SAR altimetry
df=cat.aodn.nrt_wave_sar.read()
print(len(df))
df.head
# Out:
# /home/rfonsecadasilva/anaconda3/envs/rompy-dev/lib/python3.7/site-packages/geopandas/geodataframe.py:577: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   for feature in features_lst:
# 314
# <bound method NDFrame.head of                                                 gml_id  trajectory_id  \
# 0    srs_surface_waves_sar_fv00_trajectory_map.fid-...           4559
# 1    srs_surface_waves_sar_fv00_trajectory_map.fid-...           3708
# 2    srs_surface_waves_sar_fv00_trajectory_map.fid-...           3712
# 3    srs_surface_waves_sar_fv00_trajectory_map.fid-...           3757
# 4    srs_surface_waves_sar_fv00_trajectory_map.fid-...           3710
# ..                                                 ...            ...
# 309  srs_surface_waves_sar_fv00_trajectory_map.fid-...           6090
# 310  srs_surface_waves_sar_fv00_trajectory_map.fid-...           6086
# ...
